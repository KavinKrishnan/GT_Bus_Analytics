# %%
import googlemaps

# %%
gm = googlemaps.Client('AIzaSyAq2LeYJ2JlQ0cEXcWViARgWBq8Fe4dy_0')


origins = ["Perth, Australia", "Sydney, Australia",
                   "Melbourne, Australia", "Adelaide, Australia",
                   "Brisbane, Australia", "Darwin, Australia",
                   "Hobart, Australia", "Canberra, Australia"]

destinations = ["Uluru, Australia",
                "Kakadu, Australia",
                "Blue Mountains, Australia",
                "Bungle Bungles, Australia",
                "The Pinnacles, Australia"]

gm.distance_matrix(origins,
                   destinations,
                   mode="driving",
                   avoid="tolls",
                   units="imperial")
# Out:
# {'destination_addresses': ['Uluru, Petermann NT 0872, Australia',
#   'Kakadu National Park, Kakadu Hwy, Jabiru NT 0886, Australia',
#   'Blue Mountains, New South Wales, Australia',
#   'Purnululu National Park, Western Australia 6770, Australia',
#   'Pinnacles Drive, Cervantes WA 6511, Australia'],
#  'origin_addresses': ['Perth WA, Australia',
#   'Sydney NSW, Australia',
#   'Melbourne VIC, Australia',
#   'Adelaide SA, Australia',
#   'Brisbane QLD, Australia',
#   'Darwin NT, Australia',
#   'Hobart TAS 7000, Australia',
#   'Canberra ACT 2601, Australia'],
#  'rows': [{'elements': [{'distance': {'text': '1,278 mi', 'value': 2056189},
#      'duration': {'text': '1 day 3 hours', 'value': 97333},
#      'status': 'OK'},
#     {'distance': {'text': '2,474 mi', 'value': 3981271},
#      'duration': {'text': '1 day 17 hours', 'value': 149122},
#      'status': 'OK'},
#     {'distance': {'text': '2,381 mi', 'value': 3831818},
# ...

# %%
gm = googlemaps.Client('AIzaSyAq2LeYJ2JlQ0cEXcWViARgWBq8Fe4dy_0')

origins = ["Georgia Tech Campus Recreation Center", "Georgia Tech Student Center", "Klaus Advanced Computing Building", "Tech Square"]

destinations = ["Georgia Tech Campus Recreation Center", "Georgia Tech Student Center", "Klaus Advanced Computing Building", "Tech Square"]


{"lat": 33.776112, "lng": -84.401023}

gm.distance_matrix(origins,
                   destinations,
                   mode="walking",
                   units="imperial")
# Out:
# {'destination_addresses': ['750 Ferst Dr, Atlanta, GA 30318, USA',
#   '350 Ferst Dr NW, Atlanta, GA 30332, USA',
#   '266 Ferst Dr NW, Atlanta, GA 30332, USA',
#   'Tech Square, Atlanta, GA 30308, USA'],
#  'origin_addresses': ['750 Ferst Dr, Atlanta, GA 30318, USA',
#   '350 Ferst Dr NW, Atlanta, GA 30332, USA',
#   '266 Ferst Dr NW, Atlanta, GA 30332, USA',
#   'Tech Square, Atlanta, GA 30308, USA'],
#  'rows': [{'elements': [{'distance': {'text': '1 ft', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'status': 'OK'},
#     {'distance': {'text': '0.3 mi', 'value': 494},
#      'duration': {'text': '6 mins', 'value': 346},
#      'status': 'OK'},
#     {'distance': {'text': '0.6 mi', 'value': 912},
#      'duration': {'text': '11 mins', 'value': 649},
#      'status': 'OK'},
#     {'distance': {'text': '1.0 mi', 'value': 1606},
#      'duration': {'text': '20 mins', 'value': 1203},
#      'status': 'OK'}]},
# ...
